# %% [markdown]
# ##   Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

coordinates = list(lat_lngs)

# %%
# Create a list for cities.
cities = []
# Identify latitude and longitude combination the nearest cities.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

# If city is not present ad to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count 
len(cities)
# Out:
# 755

# %%
# Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=14e1c7180bbb86b2e04d83d15d1f59e5

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
# Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

# Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
# Add 1 to the record count.
    record_count += 1       
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Country": city_country,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Current Description": city_weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kavieng
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | tsagan aman
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | havoysund
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | meiganga
# Processing Record 11 of Set 1 | bogdanovich
# Processing Record 12 of Set 1 | beloha
# Processing Record 13 of Set 1 | imeni poliny osipenko
# Processing Record 14 of Set 1 | khatanga
# Processing Record 15 of Set 1 | lompoc
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | tromso
# Processing Record 19 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 1 | yar-sale
# Processing Record 21 of Set 1 | kibakwe
# Processing Record 22 of Set 1 | huntsville
# Processing Record 23 of Set 1 | lasa
# Processing Record 24 of Set 1 | komsomolskiy
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 1 | escanaba
# Processing Record 28 of Set 1 | nuuk
# Processing Record 29 of Set 1 | valleyview
# Processing Record 30 of Set 1 | den helder
# Processing Record 31 of Set 1 | luderitz
# Processing Record 32 of Set 1 | isangel
# Processing Record 33 of Set 1 | haines junction
# Processing Record 34 of Set 1 | arlit
# Processing Record 35 of Set 1 | ostrovnoy
# Processing Record 36 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | lavrentiya
# Processing Record 39 of Set 1 | monrovia
# Processing Record 40 of Set 1 | the pas
# Processing Record 41 of Set 1 | riyadh
# Processing Record 42 of Set 1 | chokurdakh
# Processing Record 43 of Set 1 | iralaya
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | pangai
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | norman wells
# Processing Record 48 of Set 1 | waingapu
# Processing Record 49 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | didwana
# Processing Record 2 of Set 2 | north bend
# Processing Record 3 of Set 2 | salalah
# Processing Record 4 of Set 2 | provideniya
# Processing Record 5 of Set 2 | chardara
# Processing Record 6 of Set 2 | bethel
# Processing Record 7 of Set 2 | luebo
# Processing Record 8 of Set 2 | tapes
# Processing Record 9 of Set 2 | kondinskoye
# Processing Record 10 of Set 2 | saint-pierre
# Processing Record 11 of Set 2 | xudat
# Processing Record 12 of Set 2 | deputatskiy
# Processing Record 13 of Set 2 | wisconsin rapids
# Processing Record 14 of Set 2 | khandyga
# Processing Record 15 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | kaitangata
# Processing Record 19 of Set 2 | torzhok
# Processing Record 20 of Set 2 | clyde river
# Processing Record 21 of Set 2 | ilorin
# Processing Record 22 of Set 2 | jining
# Processing Record 23 of Set 2 | hermanus
# Processing Record 24 of Set 2 | lebu
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | saldanha
# Processing Record 28 of Set 2 | srednekolymsk
# Processing Record 29 of Set 2 | saskylakh
# Processing Record 30 of Set 2 | carnarvon
# Processing Record 31 of Set 2 | karpathos
# Processing Record 32 of Set 2 | dire dawa
# Processing Record 33 of Set 2 | coquimbo
# Processing Record 34 of Set 2 | goderich
# Processing Record 35 of Set 2 | ponta do sol
# Processing Record 36 of Set 2 | inhambane
# Processing Record 37 of Set 2 | hilo
# Processing Record 38 of Set 2 | mataura
# Processing Record 39 of Set 2 | tonder
# Processing Record 40 of Set 2 | labuhan
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | tiarei
# Processing Record 45 of Set 2 | oranjemund
# Processing Record 46 of Set 2 | kasongo-lunda
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | srandakan
# Processing Record 49 of Set 2 | point fortin
# Processing Record 50 of Set 2 | corinto
# Processing Record 1 of Set 3 | yellowknife
# Processing Record 2 of Set 3 | iquique
# Processing Record 3 of Set 3 | codrington
# Processing Record 4 of Set 3 | mujiayingzi
# Processing Record 5 of Set 3 | palana
# Processing Record 6 of Set 3 | rawson
# Processing Record 7 of Set 3 | saint george
# Processing Record 8 of Set 3 | new norfolk
# Processing Record 9 of Set 3 | bredasdorp
# Processing Record 10 of Set 3 | storforshei
# Processing Record 11 of Set 3 | araouane
# Processing Record 12 of Set 3 | santa cruz cabralia
# Processing Record 13 of Set 3 | victoria
# Processing Record 14 of Set 3 | port keats
# Processing Record 15 of Set 3 | tomatlan
# Processing Record 16 of Set 3 | george
# Processing Record 17 of Set 3 | westport
# Processing Record 18 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 3 | sept-iles
# Processing Record 20 of Set 3 | lumut
# Processing Record 21 of Set 3 | cherskiy
# Processing Record 22 of Set 3 | butaritari
# Processing Record 23 of Set 3 | san patricio
# Processing Record 24 of Set 3 | grajau
# Processing Record 25 of Set 3 | garissa
# Processing Record 26 of Set 3 | paita
# Processing Record 27 of Set 3 | santarem
# Processing Record 28 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 3 | souillac
# Processing Record 30 of Set 3 | contamana
# Processing Record 31 of Set 3 | omboue
# Processing Record 32 of Set 3 | labuan
# Processing Record 33 of Set 3 | karratha
# Processing Record 34 of Set 3 | lorengau
# Processing Record 35 of Set 3 | mahebourg
# Processing Record 36 of Set 3 | touros
# Processing Record 37 of Set 3 | laguna
# Processing Record 38 of Set 3 | airai
# Processing Record 39 of Set 3 | svetlaya
# Processing Record 40 of Set 3 | nikolskoye
# Processing Record 41 of Set 3 | tautira
# Processing Record 42 of Set 3 | gaoual
# Processing Record 43 of Set 3 | puerto ayora
# Processing Record 44 of Set 3 | saint-augustin
# Processing Record 45 of Set 3 | kavaratti
# Processing Record 46 of Set 3 | imbituba
# Processing Record 47 of Set 3 | strezhevoy
# Processing Record 48 of Set 3 | west wendover
# Processing Record 49 of Set 3 | hervey bay
# Processing Record 50 of Set 3 | bandar
# Processing Record 1 of Set 4 | vung tau
# Processing Record 2 of Set 4 | wanning
# Processing Record 3 of Set 4 | anadyr
# Processing Record 4 of Set 4 | tiksi
# Processing Record 5 of Set 4 | carndonagh
# Processing Record 6 of Set 4 | nouadhibou
# Processing Record 7 of Set 4 | mwinilunga
# Processing Record 8 of Set 4 | katsuura
# Processing Record 9 of Set 4 | thompson
# Processing Record 10 of Set 4 | hay river
# Processing Record 11 of Set 4 | ilo
# Processing Record 12 of Set 4 | inongo
# Processing Record 13 of Set 4 | lira
# Processing Record 14 of Set 4 | fortuna
# Processing Record 15 of Set 4 | bangkalan
# Processing Record 16 of Set 4 | vao
# Processing Record 17 of Set 4 | trofors
# Processing Record 18 of Set 4 | eureka
# Processing Record 19 of Set 4 | ribeira grande
# Processing Record 20 of Set 4 | arraial do cabo
# Processing Record 21 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 4 | vila franca do campo
# Processing Record 23 of Set 4 | iqaluit
# Processing Record 24 of Set 4 | bezopasnoye
# Processing Record 25 of Set 4 | shieli
# Processing Record 26 of Set 4 | boa vista
# Processing Record 27 of Set 4 | conakry
# Processing Record 28 of Set 4 | sorochinsk
# Processing Record 29 of Set 4 | east london
# Processing Record 30 of Set 4 | honiara
# Processing Record 31 of Set 4 | tombouctou
# Processing Record 32 of Set 4 | georgetown
# Processing Record 33 of Set 4 | tasiilaq
# Processing Record 34 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 4 | zapolyarnyy
# Processing Record 36 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 37 of Set 4 | upernavik
# Processing Record 38 of Set 4 | marsa matruh
# Processing Record 39 of Set 4 | rokytne
# Processing Record 40 of Set 4 | deep river
# Processing Record 41 of Set 4 | peniche
# Processing Record 42 of Set 4 | nome
# Processing Record 43 of Set 4 | fernley
# Processing Record 44 of Set 4 | ouango
# Processing Record 45 of Set 4 | tallahassee
# Processing Record 46 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 47 of Set 4 | narsaq
# Processing Record 48 of Set 4 | acarau
# Processing Record 49 of Set 4 | mount isa
# Processing Record 50 of Set 4 | whitehorse
# Processing Record 1 of Set 5 | ternate
# Processing Record 2 of Set 5 | castro
# Processing Record 3 of Set 5 | rio gallegos
# Processing Record 4 of Set 5 | port hardy
# Processing Record 5 of Set 5 | mayor pablo lagerenza
# Processing Record 6 of Set 5 | matara
# Processing Record 7 of Set 5 | lagoa
# Processing Record 8 of Set 5 | pitimbu
# Processing Record 9 of Set 5 | jiazi
# Processing Record 10 of Set 5 | faya
# Processing Record 11 of Set 5 | rusape
# Processing Record 12 of Set 5 | marsh harbour
# Processing Record 13 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 14 of Set 5 | galveston
# Processing Record 15 of Set 5 | bac lieu
# Processing Record 16 of Set 5 | port macquarie
# Processing Record 17 of Set 5 | cuacnopalan
# Processing Record 18 of Set 5 | cayenne
# Processing Record 19 of Set 5 | askino
# Processing Record 20 of Set 5 | bulalacao
# Processing Record 21 of Set 5 | linxia
# Processing Record 22 of Set 5 | flinders
# Processing Record 23 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 5 | kiama
# Processing Record 25 of Set 5 | sinnamary
# Processing Record 26 of Set 5 | kodiak
# Processing Record 27 of Set 5 | tarakan
# Processing Record 28 of Set 5 | caravelas
# Processing Record 29 of Set 5 | batagay
# Processing Record 30 of Set 5 | oktyabrskiy
# Processing Record 31 of Set 5 | qaqortoq
# Processing Record 32 of Set 5 | alyangula
# Processing Record 33 of Set 5 | san andres
# Processing Record 34 of Set 5 | zverinogolovskoye
# Processing Record 35 of Set 5 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 36 of Set 5 | jacareacanga
# Processing Record 37 of Set 5 | mar del plata
# Processing Record 38 of Set 5 | felipe carrillo puerto
# Processing Record 39 of Set 5 | geraldton
# Processing Record 40 of Set 5 | pacific grove
# Processing Record 41 of Set 5 | dudinka
# Processing Record 42 of Set 5 | san quintin
# Processing Record 43 of Set 5 | vardo
# Processing Record 44 of Set 5 | puerto madero
# Processing Record 45 of Set 5 | krasnozerskoye
# Processing Record 46 of Set 5 | bandar-e lengeh
# Processing Record 47 of Set 5 | celestun
# Processing Record 48 of Set 5 | ouargaye
# Processing Record 49 of Set 5 | chumikan
# Processing Record 50 of Set 5 | moanda
# Processing Record 1 of Set 6 | gondanglegi
# Processing Record 2 of Set 6 | richards bay
# Processing Record 3 of Set 6 | torbay
# Processing Record 4 of Set 6 | esperance
# Processing Record 5 of Set 6 | padang
# Processing Record 6 of Set 6 | gimli
# Processing Record 7 of Set 6 | aitape
# Processing Record 8 of Set 6 | raga
# Processing Record 9 of Set 6 | mogadishu
# Processing Record 10 of Set 6 | panaba
# Processing Record 11 of Set 6 | kidal
# Processing Record 12 of Set 6 | faanui
# Processing Record 13 of Set 6 | vila
# Processing Record 14 of Set 6 | witney
# Processing Record 15 of Set 6 | flin flon
# Processing Record 16 of Set 6 | lukovetskiy
# Processing Record 17 of Set 6 | uyemskiy
# Processing Record 18 of Set 6 | bambous virieux
# Processing Record 19 of Set 6 | luganville
# Processing Record 20 of Set 6 | midland
# Processing Record 21 of Set 6 | sioux lookout
# Processing Record 22 of Set 6 | santa rosa
# Processing Record 23 of Set 6 | ferrol
# Processing Record 24 of Set 6 | mizpe ramon
# City not found. Skipping...
# Processing Record 25 of Set 6 | cabo san lucas
# Processing Record 26 of Set 6 | pevek
# Processing Record 27 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 6 | mitzic
# Processing Record 29 of Set 6 | hambantota
# Processing Record 30 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 6 | kerema
# Processing Record 32 of Set 6 | el faiyum
# City not found. Skipping...
# Processing Record 33 of Set 6 | beyneu
# Processing Record 34 of Set 6 | hobart
# Processing Record 35 of Set 6 | provost
# Processing Record 36 of Set 6 | hualmay
# Processing Record 37 of Set 6 | tres passos
# Processing Record 38 of Set 6 | kizukuri
# Processing Record 39 of Set 6 | itupiranga
# Processing Record 40 of Set 6 | gorontalo
# Processing Record 41 of Set 6 | constitucion
# Processing Record 42 of Set 6 | rock sound
# Processing Record 43 of Set 6 | sisimiut
# Processing Record 44 of Set 6 | ambilobe
# Processing Record 45 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 6 | longyearbyen
# Processing Record 47 of Set 6 | hajnowka
# Processing Record 48 of Set 6 | vostok
# Processing Record 49 of Set 6 | soe
# Processing Record 50 of Set 6 | santos reyes nopala
# Processing Record 1 of Set 7 | beidao
# Processing Record 2 of Set 7 | nairn
# Processing Record 3 of Set 7 | hirara
# Processing Record 4 of Set 7 | ossora
# Processing Record 5 of Set 7 | atocha
# Processing Record 6 of Set 7 | fairbanks
# Processing Record 7 of Set 7 | yarada
# Processing Record 8 of Set 7 | bubaque
# Processing Record 9 of Set 7 | marystown
# Processing Record 10 of Set 7 | cheyenne
# Processing Record 11 of Set 7 | ketchikan
# Processing Record 12 of Set 7 | diamantina
# Processing Record 13 of Set 7 | taoudenni
# Processing Record 14 of Set 7 | del gallego
# Processing Record 15 of Set 7 | zhigansk
# Processing Record 16 of Set 7 | klaksvik
# Processing Record 17 of Set 7 | elhovo
# Processing Record 18 of Set 7 | lensk
# Processing Record 19 of Set 7 | ilulissat
# Processing Record 20 of Set 7 | ziarat
# Processing Record 21 of Set 7 | gat
# Processing Record 22 of Set 7 | burica
# City not found. Skipping...
# Processing Record 23 of Set 7 | itarema
# Processing Record 24 of Set 7 | margate
# Processing Record 25 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 7 | vila velha
# Processing Record 27 of Set 7 | altenholz
# Processing Record 28 of Set 7 | baruun-urt
# Processing Record 29 of Set 7 | shingu
# Processing Record 30 of Set 7 | talnakh
# Processing Record 31 of Set 7 | pimenteiras
# Processing Record 32 of Set 7 | shubarkuduk
# Processing Record 33 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 7 | aasiaat
# Processing Record 35 of Set 7 | sambava
# Processing Record 36 of Set 7 | ancud
# Processing Record 37 of Set 7 | bengkulu
# Processing Record 38 of Set 7 | la romana
# Processing Record 39 of Set 7 | chuy
# Processing Record 40 of Set 7 | nexo
# Processing Record 41 of Set 7 | sao joao da barra
# Processing Record 42 of Set 7 | poum
# Processing Record 43 of Set 7 | rocha
# Processing Record 44 of Set 7 | racine
# Processing Record 45 of Set 7 | teya
# Processing Record 46 of Set 7 | porterville
# Processing Record 47 of Set 7 | demyansk
# Processing Record 48 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 7 | faridpur
# Processing Record 50 of Set 7 | tabou
# Processing Record 1 of Set 8 | sokolo
# Processing Record 2 of Set 8 | yumbe
# Processing Record 3 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 8 | kiknur
# Processing Record 5 of Set 8 | carutapera
# Processing Record 6 of Set 8 | po
# City not found. Skipping...
# Processing Record 7 of Set 8 | urumqi
# Processing Record 8 of Set 8 | acari
# Processing Record 9 of Set 8 | crib point
# Processing Record 10 of Set 8 | beroroha
# Processing Record 11 of Set 8 | port elizabeth
# Processing Record 12 of Set 8 | asau
# Processing Record 13 of Set 8 | sao filipe
# Processing Record 14 of Set 8 | pangnirtung
# Processing Record 15 of Set 8 | menongue
# Processing Record 16 of Set 8 | kalabo
# Processing Record 17 of Set 8 | aswan
# Processing Record 18 of Set 8 | kashi
# Processing Record 19 of Set 8 | biak
# Processing Record 20 of Set 8 | ghanzi
# Processing Record 21 of Set 8 | lemesos
# City not found. Skipping...
# Processing Record 22 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 23 of Set 8 | barra do garcas
# Processing Record 24 of Set 8 | luanda
# Processing Record 25 of Set 8 | najran
# Processing Record 26 of Set 8 | villanueva de la serena
# Processing Record 27 of Set 8 | vlasotince
# Processing Record 28 of Set 8 | koshurnikovo
# Processing Record 29 of Set 8 | pedernales
# Processing Record 30 of Set 8 | henties bay
# Processing Record 31 of Set 8 | grand gaube
# Processing Record 32 of Set 8 | okandja
# City not found. Skipping...
# Processing Record 33 of Set 8 | namatanai
# Processing Record 34 of Set 8 | okahandja
# Processing Record 35 of Set 8 | elko
# Processing Record 36 of Set 8 | kolda
# Processing Record 37 of Set 8 | odweyne
# Processing Record 38 of Set 8 | mwanza
# Processing Record 39 of Set 8 | jhudo
# Processing Record 40 of Set 8 | kamenka
# Processing Record 41 of Set 8 | bhanpuri
# Processing Record 42 of Set 8 | kloulklubed
# Processing Record 43 of Set 8 | kouango
# Processing Record 44 of Set 8 | severo-kurilsk
# Processing Record 45 of Set 8 | port moresby
# Processing Record 46 of Set 8 | conway
# Processing Record 47 of Set 8 | coolum beach
# Processing Record 48 of Set 8 | havelock
# Processing Record 49 of Set 8 | wilmington
# Processing Record 50 of Set 8 | namibe
# Processing Record 1 of Set 9 | mamallapuram
# Processing Record 2 of Set 9 | cidreira
# Processing Record 3 of Set 9 | bokspits
# City not found. Skipping...
# Processing Record 4 of Set 9 | hofn
# Processing Record 5 of Set 9 | villacarrillo
# Processing Record 6 of Set 9 | bongandanga
# Processing Record 7 of Set 9 | banda aceh
# Processing Record 8 of Set 9 | guayaramerin
# Processing Record 9 of Set 9 | ballina
# Processing Record 10 of Set 9 | zyryanovsk
# Processing Record 11 of Set 9 | kahului
# Processing Record 12 of Set 9 | lodwar
# Processing Record 13 of Set 9 | jalu
# Processing Record 14 of Set 9 | bandarbeyla
# Processing Record 15 of Set 9 | bilibino
# Processing Record 16 of Set 9 | moussoro
# Processing Record 17 of Set 9 | sao miguel do araguaia
# Processing Record 18 of Set 9 | trairi
# Processing Record 19 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 20 of Set 9 | chapais
# Processing Record 21 of Set 9 | hasaki
# Processing Record 22 of Set 9 | olinda
# Processing Record 23 of Set 9 | pisco
# Processing Record 24 of Set 9 | luba
# Processing Record 25 of Set 9 | kamina
# Processing Record 26 of Set 9 | lufilufi
# Processing Record 27 of Set 9 | port blair
# Processing Record 28 of Set 9 | atasu
# Processing Record 29 of Set 9 | vestmannaeyjar
# Processing Record 30 of Set 9 | alofi
# Processing Record 31 of Set 9 | ca mau
# Processing Record 32 of Set 9 | maningrida
# Processing Record 33 of Set 9 | roald
# Processing Record 34 of Set 9 | makakilo city
# Processing Record 35 of Set 9 | poddorye
# Processing Record 36 of Set 9 | tual
# Processing Record 37 of Set 9 | sakakah
# Processing Record 38 of Set 9 | kathmandu
# Processing Record 39 of Set 9 | antalaha
# Processing Record 40 of Set 9 | gainesville
# Processing Record 41 of Set 9 | sal rei
# Processing Record 42 of Set 9 | genhe
# Processing Record 43 of Set 9 | aakirkeby
# City not found. Skipping...
# Processing Record 44 of Set 9 | junnar
# Processing Record 45 of Set 9 | janauba
# Processing Record 46 of Set 9 | daru
# Processing Record 47 of Set 9 | caarapo
# Processing Record 48 of Set 9 | mareeba
# Processing Record 49 of Set 9 | moa
# Processing Record 50 of Set 9 | huazolotitlan
# City not found. Skipping...
# Processing Record 1 of Set 10 | konstantinovo
# Processing Record 2 of Set 10 | polson
# Processing Record 3 of Set 10 | darnah
# Processing Record 4 of Set 10 | mount gambier
# Processing Record 5 of Set 10 | topolobampo
# Processing Record 6 of Set 10 | guerrero negro
# Processing Record 7 of Set 10 | melchor de mencos
# Processing Record 8 of Set 10 | saint anthony
# Processing Record 9 of Set 10 | port hedland
# Processing Record 10 of Set 10 | locri
# Processing Record 11 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 10 | sahuaripa
# Processing Record 13 of Set 10 | yumen
# Processing Record 14 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 15 of Set 10 | ahipara
# Processing Record 16 of Set 10 | ginda
# Processing Record 17 of Set 10 | mehamn
# Processing Record 18 of Set 10 | angoche
# Processing Record 19 of Set 10 | aransas pass
# Processing Record 20 of Set 10 | quelimane
# Processing Record 21 of Set 10 | crossfield
# Processing Record 22 of Set 10 | yeppoon
# Processing Record 23 of Set 10 | cupseni
# Processing Record 24 of Set 10 | clovis
# Processing Record 25 of Set 10 | bonthe
# Processing Record 26 of Set 10 | mount pleasant
# Processing Record 27 of Set 10 | nanortalik
# Processing Record 28 of Set 10 | kofarnihon
# City not found. Skipping...
# Processing Record 29 of Set 10 | alugan
# Processing Record 30 of Set 10 | boatlaname
# City not found. Skipping...
# Processing Record 31 of Set 10 | los llanos de aridane
# Processing Record 32 of Set 10 | peterhead
# Processing Record 33 of Set 10 | bossangoa
# Processing Record 34 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 35 of Set 10 | mandali
# Processing Record 36 of Set 10 | yiyang
# Processing Record 37 of Set 10 | sitka
# Processing Record 38 of Set 10 | oriximina
# Processing Record 39 of Set 10 | dekar
# Processing Record 40 of Set 10 | kassala
# Processing Record 41 of Set 10 | youkounkoun
# Processing Record 42 of Set 10 | kieta
# Processing Record 43 of Set 10 | yaan
# Processing Record 44 of Set 10 | hearst
# Processing Record 45 of Set 10 | teahupoo
# Processing Record 46 of Set 10 | wattegama
# Processing Record 47 of Set 10 | diadema
# Processing Record 48 of Set 10 | setermoen
# Processing Record 49 of Set 10 | broome
# Processing Record 50 of Set 10 | zunyi
# Processing Record 1 of Set 11 | taganak
# Processing Record 2 of Set 11 | kutum
# Processing Record 3 of Set 11 | leningradskiy
# Processing Record 4 of Set 11 | yining
# Processing Record 5 of Set 11 | comodoro rivadavia
# Processing Record 6 of Set 11 | shilka
# Processing Record 7 of Set 11 | crailsheim
# Processing Record 8 of Set 11 | ouallam
# Processing Record 9 of Set 11 | sarakhs
# Processing Record 10 of Set 11 | nago
# Processing Record 11 of Set 11 | abu dhabi
# Processing Record 12 of Set 11 | esmeralda
# Processing Record 13 of Set 11 | yulara
# Processing Record 14 of Set 11 | te anau
# Processing Record 15 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 11 | stephenville
# Processing Record 17 of Set 11 | zaysan
# Processing Record 18 of Set 11 | tateyama
# Processing Record 19 of Set 11 | mont-dore
# Processing Record 20 of Set 11 | zhezkazgan
# Processing Record 21 of Set 11 | maryborough
# Processing Record 22 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 11 | susehri
# Processing Record 24 of Set 11 | dinguiraye
# Processing Record 25 of Set 11 | san cristobal
# Processing Record 26 of Set 11 | ojinaga
# Processing Record 27 of Set 11 | umm ruwabah
# City not found. Skipping...
# Processing Record 28 of Set 11 | walvis bay
# Processing Record 29 of Set 11 | honningsvag
# Processing Record 30 of Set 11 | shimoda
# Processing Record 31 of Set 11 | slantsy
# Processing Record 32 of Set 11 | grindavik
# Processing Record 33 of Set 11 | solaro
# Processing Record 34 of Set 11 | soyo
# Processing Record 35 of Set 11 | ko samui
# Processing Record 36 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 37 of Set 11 | debre birhan
# Processing Record 38 of Set 11 | emerald
# Processing Record 39 of Set 11 | lewisporte
# Processing Record 40 of Set 11 | kargil
# Processing Record 41 of Set 11 | massaguet
# Processing Record 42 of Set 11 | nerchinsk
# Processing Record 43 of Set 11 | lazaro cardenas
# Processing Record 44 of Set 11 | chany
# Processing Record 45 of Set 11 | muros
# Processing Record 46 of Set 11 | ryotsu
# Processing Record 47 of Set 11 | dire
# Processing Record 48 of Set 11 | necochea
# Processing Record 49 of Set 11 | kumluca
# Processing Record 50 of Set 11 | thunder bay
# Processing Record 1 of Set 12 | nekhayevskiy
# Processing Record 2 of Set 12 | kruisfontein
# Processing Record 3 of Set 12 | grakhovo
# Processing Record 4 of Set 12 | molina
# Processing Record 5 of Set 12 | misratah
# Processing Record 6 of Set 12 | champerico
# Processing Record 7 of Set 12 | puerto madryn
# Processing Record 8 of Set 12 | ilanskiy
# Processing Record 9 of Set 12 | vakhrushev
# Processing Record 10 of Set 12 | zarate
# Processing Record 11 of Set 12 | gavrilovka vtoraya
# Processing Record 12 of Set 12 | viedma
# Processing Record 13 of Set 12 | pasni
# Processing Record 14 of Set 12 | sola
# Processing Record 15 of Set 12 | aberfoyle
# Processing Record 16 of Set 12 | christchurch
# Processing Record 17 of Set 12 | conde
# Processing Record 18 of Set 12 | fairview
# Processing Record 19 of Set 12 | mineros
# Processing Record 20 of Set 12 | manzhouli
# Processing Record 21 of Set 12 | molochnoye
# Processing Record 22 of Set 12 | plainview
# Processing Record 23 of Set 12 | ambon
# Processing Record 24 of Set 12 | dwarka
# Processing Record 25 of Set 12 | redcar
# Processing Record 26 of Set 12 | gamba
# Processing Record 27 of Set 12 | spornoye
# Processing Record 28 of Set 12 | san ignacio
# Processing Record 29 of Set 12 | guangyuan
# Processing Record 30 of Set 12 | ayr
# Processing Record 31 of Set 12 | karema
# Processing Record 32 of Set 12 | gigmoto
# Processing Record 33 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 34 of Set 12 | hamilton
# Processing Record 35 of Set 12 | sassandra
# Processing Record 36 of Set 12 | omsukchan
# Processing Record 37 of Set 12 | launceston
# Processing Record 38 of Set 12 | minot
# Processing Record 39 of Set 12 | vanersborg
# Processing Record 40 of Set 12 | dong hoi
# Processing Record 41 of Set 12 | belaya gora
# Processing Record 42 of Set 12 | stornoway
# Processing Record 43 of Set 12 | marzuq
# Processing Record 44 of Set 12 | ostersund
# Processing Record 45 of Set 12 | kropotkin
# Processing Record 46 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 12 | kresttsy
# Processing Record 48 of Set 12 | acandi
# Processing Record 49 of Set 12 | glomfjord
# Processing Record 50 of Set 12 | almeirim
# Processing Record 1 of Set 13 | tharrawaddy
# City not found. Skipping...
# Processing Record 2 of Set 13 | armidale
# Processing Record 3 of Set 13 | lethem
# Processing Record 4 of Set 13 | miandrivazo
# Processing Record 5 of Set 13 | eenhana
# Processing Record 6 of Set 13 | ola
# Processing Record 7 of Set 13 | panguna
# Processing Record 8 of Set 13 | bantry
# Processing Record 9 of Set 13 | bulgan
# Processing Record 10 of Set 13 | gossas
# Processing Record 11 of Set 13 | fort portal
# Processing Record 12 of Set 13 | veraval
# Processing Record 13 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 14 of Set 13 | mancio lima
# Processing Record 15 of Set 13 | chiredzi
# Processing Record 16 of Set 13 | astaneh-ye ashrafiyeh
# Processing Record 17 of Set 13 | okha
# Processing Record 18 of Set 13 | methoni
# Processing Record 19 of Set 13 | mangrol
# Processing Record 20 of Set 13 | turtkul
# City not found. Skipping...
# Processing Record 21 of Set 13 | yafran
# Processing Record 22 of Set 13 | mayo
# Processing Record 23 of Set 13 | moba
# Processing Record 24 of Set 13 | bodden town
# Processing Record 25 of Set 13 | huatulco
# Processing Record 26 of Set 13 | kesennuma
# City not found. Skipping...
# Processing Record 27 of Set 13 | novosokolniki
# Processing Record 28 of Set 13 | xingyi
# Processing Record 29 of Set 13 | solnechnyy
# Processing Record 30 of Set 13 | adrar
# Processing Record 31 of Set 13 | gaogou
# Processing Record 32 of Set 13 | salinas
# Processing Record 33 of Set 13 | malumfashi
# Processing Record 34 of Set 13 | plettenberg bay
# Processing Record 35 of Set 13 | kemerovo
# Processing Record 36 of Set 13 | ozernovskiy
# Processing Record 37 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 13 | la ronge
# Processing Record 39 of Set 13 | cap-haitien
# Processing Record 40 of Set 13 | nabannagan
# Processing Record 41 of Set 13 | dongsheng
# Processing Record 42 of Set 13 | sneek
# Processing Record 43 of Set 13 | magugu
# Processing Record 44 of Set 13 | fare
# Processing Record 45 of Set 13 | kalat
# Processing Record 46 of Set 13 | jinchang
# Processing Record 47 of Set 13 | zhanaozen
# Processing Record 48 of Set 13 | joensuu
# Processing Record 49 of Set 13 | koungou
# Processing Record 50 of Set 13 | sinjai
# Processing Record 1 of Set 14 | catuday
# Processing Record 2 of Set 14 | alta floresta
# Processing Record 3 of Set 14 | nagar karnul
# Processing Record 4 of Set 14 | taree
# Processing Record 5 of Set 14 | nieuw amsterdam
# Processing Record 6 of Set 14 | robat karim
# Processing Record 7 of Set 14 | merritt island
# Processing Record 8 of Set 14 | college
# Processing Record 9 of Set 14 | pollachi
# Processing Record 10 of Set 14 | changchun
# Processing Record 11 of Set 14 | iwanai
# Processing Record 12 of Set 14 | xucheng
# Processing Record 13 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 14 | bina-etawa
# City not found. Skipping...
# Processing Record 15 of Set 14 | jambi
# Processing Record 16 of Set 14 | erenhot
# Processing Record 17 of Set 14 | namwala
# Processing Record 18 of Set 14 | innisfail
# Processing Record 19 of Set 14 | chernaya kholunitsa
# Processing Record 20 of Set 14 | port arthur
# Processing Record 21 of Set 14 | manokwari
# Processing Record 22 of Set 14 | meulaboh
# Processing Record 23 of Set 14 | soars
# Processing Record 24 of Set 14 | hovd
# Processing Record 25 of Set 14 | xinzhi
# Processing Record 26 of Set 14 | zeya
# Processing Record 27 of Set 14 | auki
# Processing Record 28 of Set 14 | lodja
# Processing Record 29 of Set 14 | berlin
# Processing Record 30 of Set 14 | saint-joseph
# Processing Record 31 of Set 14 | bonavista
# Processing Record 32 of Set 14 | jijiga
# Processing Record 33 of Set 14 | martinsicuro
# Processing Record 34 of Set 14 | bama
# Processing Record 35 of Set 14 | zhangye
# Processing Record 36 of Set 14 | malanje
# Processing Record 37 of Set 14 | quang ngai
# Processing Record 38 of Set 14 | awbari
# Processing Record 39 of Set 14 | cooma
# Processing Record 40 of Set 14 | khomeynishahr
# City not found. Skipping...
# Processing Record 41 of Set 14 | yanai
# Processing Record 42 of Set 14 | deneysville
# Processing Record 43 of Set 14 | ingham
# Processing Record 44 of Set 14 | chibombo
# Processing Record 45 of Set 14 | ponta delgada
# Processing Record 46 of Set 14 | qafsah
# City not found. Skipping...
# Processing Record 47 of Set 14 | kibondo
# Processing Record 48 of Set 14 | keti bandar
# Processing Record 49 of Set 14 | veracruz
# Processing Record 50 of Set 14 | anzio
# Processing Record 1 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 2 of Set 15 | sidi ali
# Processing Record 3 of Set 15 | arman
# Processing Record 4 of Set 15 | ahuimanu
# Processing Record 5 of Set 15 | payo
# Processing Record 6 of Set 15 | aksu
# Processing Record 7 of Set 15 | shelburne
# Processing Record 8 of Set 15 | itoman
# Processing Record 9 of Set 15 | hauterive
# Processing Record 10 of Set 15 | pombas
# Processing Record 11 of Set 15 | altay
# Processing Record 12 of Set 15 | chapleau
# Processing Record 13 of Set 15 | nchelenge
# Processing Record 14 of Set 15 | kepno
# Processing Record 15 of Set 15 | nanchong
# Processing Record 16 of Set 15 | snezhnogorsk
# Processing Record 17 of Set 15 | portland
# Processing Record 18 of Set 15 | lokosovo
# Processing Record 19 of Set 15 | amapa
# Processing Record 20 of Set 15 | cullera
# Processing Record 21 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 15 | fomboni
# Processing Record 23 of Set 15 | pandan
# Processing Record 24 of Set 15 | maromitsa
# Processing Record 25 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 15 | muzhi
# Processing Record 27 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 28 of Set 15 | upington
# Processing Record 29 of Set 15 | yoichi
# Processing Record 30 of Set 15 | hua hin
# Processing Record 31 of Set 15 | udachnyy
# Processing Record 32 of Set 15 | cabuyaro
# Processing Record 33 of Set 15 | bathsheba
# Processing Record 34 of Set 15 | liniere
# City not found. Skipping...
# Processing Record 35 of Set 15 | oussouye
# Processing Record 36 of Set 15 | sur
# Processing Record 37 of Set 15 | bereda
# Processing Record 38 of Set 15 | pinega
# Processing Record 39 of Set 15 | kodinsk
# Processing Record 40 of Set 15 | rio cuarto
# Processing Record 41 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 15 | shakhtinsk
# Processing Record 43 of Set 15 | carberry
# Processing Record 44 of Set 15 | santa maria
# Processing Record 45 of Set 15 | tutoia
# Processing Record 46 of Set 15 | nabire
# Processing Record 47 of Set 15 | revda
# Processing Record 48 of Set 15 | mathathane
# Processing Record 49 of Set 15 | kolosovka
# Processing Record 50 of Set 15 | camacha
# Processing Record 1 of Set 16 | okhotsk
# Processing Record 2 of Set 16 | san luis
# Processing Record 3 of Set 16 | ati
# Processing Record 4 of Set 16 | vinh
# Processing Record 5 of Set 16 | verkhnetulomskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Kavieng      PG  -2.5744  150.7967     81.73        75          98
# 1    Busselton      AU -33.6500  115.3333     63.09        88          27
# 2    Cape Town      ZA -33.9258   18.4232     76.87        61           0
# 3  Tsagan Aman      RU  47.5639   46.7218     35.46        82          79
# 4        Kapaa      US  22.0752 -159.3190     67.98        94           0
# 5  Port Alfred      ZA -33.5906   26.8910     73.45        72           1
# 6    Havoysund      NO  70.9963   24.6622     30.43        59         100
# 7       Atuona      PF  -9.8000 -139.0333     77.09        78          24
# 8     Meiganga      CM   6.5167   14.3000     88.66        12           2
# 9  Bogdanovich      RU  56.7803   62.0494     11.52        95         100
#
#    Wind Speed Current Description
# 0        6.31          light rain
# 1        6.73    scattered clouds
# 2       18.41           clear sky
# 3        9.17       broken clouds
# 4       10.36           clear sky
# 5        6.53           clear sky
# 6       23.35     overcast clouds
# 7       15.46          light rain
# 8       10.13           clear sky
# 9       12.50          light snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
